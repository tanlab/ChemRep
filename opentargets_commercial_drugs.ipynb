# %%
#!/usr/bin/env python3

import requests
import json

# %%
import ast

# %%
from jsonmerge import merge

# %%
diseases={
  "name": "GEO Signatures of Differentially Expressed Genes for Diseases",
  "resource": {
    "name": "Gene Expression Omnibus",
    "href": "/api/1.0/resource/Gene+Expression+Omnibus"
  },
  "association": "gene-disease associations by differential expression of gene following disease perturbation",
  "description": "mRNA expression profiles for cell lines or tissues following disease perturbation",
  "datasetGroup": "transcriptomics",
  "measurement": "gene expression by microarray",
  "attributeGroup": "disease, phenotype or trait",
  "attributeType": "disease perturbation",
  "pubMedIds": [
    23193258,
    19756046,
    11752295
  ],
  "geneSets": [
    {
      "name": "Acne_Sebocyte_GSE10432/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Acne_Sebocyte_GSE10432/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Actinic keratosis_Skin tissue_GSE2503/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Actinic+keratosis_Skin+tissue_GSE2503/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Acute Lung Injury_Lung Tissue_GSE1871/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Acute+Lung+Injury_Lung+Tissue_GSE1871/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Acute Lung Injury_Whole blood_GSE10474/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Acute+Lung+Injury_Whole+blood_GSE10474/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Acute pancreatitis_Pancreas_GSE3644/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Acute+pancreatitis_Pancreas_GSE3644/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Adenocarcinoma of lung_Lung Tissue_GSE1037/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Adenocarcinoma+of+lung_Lung+Tissue_GSE1037/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Adenocarcinoma of lung_Lung Tissue_GSE11969/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Adenocarcinoma+of+lung_Lung+Tissue_GSE11969/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Adenoma of small intestine_Intestinal Epithelium_GSE422/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Adenoma+of+small+intestine_Intestinal+Epithelium_GSE422/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Adenoma_Adrenal gland_GSE8514/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Adenoma_Adrenal+gland_GSE8514/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Adenoma_Colon_GSE4183/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Adenoma_Colon_GSE4183/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Alcohol poisoning_Pancreas_GSE3311/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Alcohol+poisoning_Pancreas_GSE3311/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Alexander Disease_CNS - Brain - Olfactory Bulb (MMHCC)_GSE977/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Alexander+Disease_CNS+-+Brain+-+Olfactory+Bulb+%28MMHCC%29_GSE977/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Alzheimer\\u0027s Disease_CNS - Brain - Hippocampus (MMHCC)_GSE1297/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Alzheimer%27s+Disease_CNS+-+Brain+-+Hippocampus+%28MMHCC%29_GSE1297/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Alzheimer\\u0027s Disease_Entorhinal cortex_GSE5281/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Alzheimer%27s+Disease_Entorhinal+cortex_GSE5281/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "AML - Acute myeloid leukemia_Mononuclear Leukocyte_GSE2191/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/AML+-+Acute+myeloid+leukemia_Mononuclear+Leukocyte_GSE2191/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Anaplasmosis_Leukemic Cell_GSE2600/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Anaplasmosis_Leukemic+Cell_GSE2600/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Androgen insensitivity syndrome_Fibroblast_GSE3871/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Androgen+insensitivity+syndrome_Fibroblast_GSE3871/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Ankylosing Spondylitides_macrophage_GSE11886/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Ankylosing+Spondylitides_macrophage_GSE11886/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "APECED - Autoimmune polyendocrinopathy-candidiasis-ectodermal dystrophy_Thymic epithelial cell_GSE85/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/APECED+-+Autoimmune+polyendocrinopathy-candidiasis-ectodermal+dystrophy_Thymic+epithelial+cell_GSE85/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Appendicitis_Appendix_GSE9579/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Appendicitis_Appendix_GSE9579/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "
GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Type 2 diabetes mellitus_Hepatic Tissue_GSE2899/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Type+2+diabetes+mellitus_Hepatic+Tissue_GSE2899/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Type 2 diabetes mellitus_Muscle tissue_GSE12643/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Type+2+diabetes+mellitus_Muscle+tissue_GSE12643/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Type 2 diabetes mellitus_Pancreas_GSE2470/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Type+2+diabetes+mellitus_Pancreas_GSE2470/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Type 2 diabetes mellitus_Renal Tissue_GSE642/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Type+2+diabetes+mellitus_Renal+Tissue_GSE642/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Ulcerative Colitis_Peripheral blood mononuclear cell_GSE3365/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Ulcerative+Colitis_Peripheral+blood+mononuclear+cell_GSE3365/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Urothelial carcinoma_Urothelium_GSE3167/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Urothelial+carcinoma_Urothelium_GSE3167/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Uterine leiomyoma_Uterus - Myometrium (MMHCC)_GSE593/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Uterine+leiomyoma_Uterus+-+Myometrium+%28MMHCC%29_GSE593/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Uterine leiomyoma_Uterus_GSE2724/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Uterine+leiomyoma_Uterus_GSE2724/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Uterine leiomyoma_Uterus_GSE2725/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Uterine+leiomyoma_Uterus_GSE2725/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Ventilator-associated lung injury_Lung Tissue_GSE2411/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Ventilator-associated+lung+injury_Lung+Tissue_GSE2411/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Ventricular hypertrophy_Myocardial tissue_GSE4678/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Ventricular+hypertrophy_Myocardial+tissue_GSE4678/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Viral cardiomyopathy_Myocardial tissue_GSE4172/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Viral+cardiomyopathy_Myocardial+tissue_GSE4172/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Whipple\\u0027s Disease_macrophage_GSE16180/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Whipple%27s+Disease_macrophage_GSE16180/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    },
    {
      "name": "Yersinia enterocolitica food poisoning_Peyer\\u0027s patch_GSE4764/GEO Signatures of Differentially Expressed Genes for Diseases",
      "href": "/api/1.0/gene_set/Yersinia+enterocolitica+food+poisoning_Peyer%27s+patch_GSE4764/GEO+Signatures+of+Differentially+Expressed+Genes+for+Diseases"
    }
  ]
}

# %%
disease_list = []
for i in range(len(diseases['geneSets'])):
    disease_list.append(diseases['geneSets'][i]['name'].split('_')[0])

# %%
disease_list =list(dict.fromkeys(disease_list))

# %%
disease_list
# Out:
# ['Acne',
#  'Actinic keratosis',
#  'Acute Lung Injury',
#  'Acute pancreatitis',
#  'Adenocarcinoma of lung',
#  'Adenoma of small intestine',
#  'Adenoma',
#  'Alcohol poisoning',
#  'Alexander Disease',
#  'Alzheimer\\u0027s Disease',
#  'AML - Acute myeloid leukemia',
#  'Anaplasmosis',
#  'Androgen insensitivity syndrome',
#  'Ankylosing Spondylitides',
#  'APECED - Autoimmune polyendocrinopathy-candidiasis-ectodermal dystrophy',
#  'Appendicitis',
#  'Arrhythmogenic Right Ventricular Cardiomyopathy',
#  'Asthma, allergic',
#  'Asthma',
#  'Astrocytoma',
#  'Atherosclerosis',
#  'B-cell chronic lymphocytic leukaemia-small lymphocytic lymphoma',
#  'Bacterial Infection',
#  'Barrett Esophagus',
#  'Bipolar Disorder',
#  'Breast Cancer',
#  'Cancer of Colon',
#  'Cancer of prostate',
#  'Cancer of the testis',
#  'Cancer of thyroid',
#  'Carcinoma, Hepatocellular',
#  'Cardiac Failure',
#  'Cardiac Hypertrophy',
#  'Cardiomyopathy, Dilated',
#  'Cardiomyopathy',
# ...

# %%
returns = []
for disease in disease_list:
    try:
        query_string = """query search($disease: String!){
            search(queryString:$disease, entityNames:"disease"){
            hits{
              name
              id
            }
          }
          }"""
        # Set variables object of arguments to be passed to endpoint

        # Set base URL of GraphQL API endpoint
        base_url = "https://api.platform.opentargets.org/api/v4/graphql"
        variables = {"disease": disease}
        # Perform POST request and check status code of response
        r = requests.post(base_url, json={"query": query_string, "variables": variables})
        print(r.status_code)

        # Transform API response into JSON 
        api_response_as_json = json.loads(r.text)
        returns.append((api_response_as_json['data']['search']['hits'][0]['name'],api_response_as_json['data']['search']['hits'][0]['id']))
        # Print API response to terminal
        print(api_response_as_json['data']['search']['hits'][0])
    except:
        continue
# Out:
# 200
# {'name': 'acne', 'id': 'EFO_0003894'}
# 200
# {'name': 'actinic keratosis', 'id': 'EFO_0002496'}
# 200
# {'name': 'acute lung injury', 'id': 'EFO_0004610'}
# 200
# {'name': 'acute pancreatitis', 'id': 'EFO_1000652'}
# 200
# {'name': 'lung adenocarcinoma', 'id': 'EFO_0000571'}
# 200
# 200
# {'name': 'adenoma', 'id': 'EFO_0000232'}
# 200
# {'name': 'alcoholic psychosis', 'id': 'EFO_1001260'}
# 200
# {'name': 'Alexander disease', 'id': 'Orphanet_58'}
# 200
# 200
# {'name': 'acute myeloid leukemia', 'id': 'EFO_0000222'}
# 200
# {'name': 'Androgen insensitivity syndrome', 'id': 'Orphanet_754'}
# 200
# 200
# 200
# {'name': 'appendicitis', 'id': 'EFO_0007149'}
# 200
# {'name': 'Arrhythmogenic right ventricular dysplasia', 'id': 'Orphanet_247'}
# 200
# {'name': 'atopic eczema', 'id': 'EFO_0000274'}
# 200
# {'name': 'asthma', 'id': 'EFO_0000270'}
# 200
# {'name': 'astrocytoma', 'id': 'EFO_0000272'}
# 200
# {'name': 'atherosclerosis', 'id': 'EFO_0003914'}
# 200
# 200
# ...

# %%
import pandas as pd
pd.DataFrame(returns,columns=['name','id']).to_csv('harmonizome_disease_list.csv',index=False)

# %%
data2 = {} 
count = 0
# Set gene_id variable
for name,eid in returns:
    try:
        # Build query string
        query_string = """query disease($eid: String!){ 
          disease(efoId:$eid) {
            name
            knownDrugs{
              rows{
                drugId
                prefName
              }
            }
          }
        }
        """
        # Set variables object of arguments to be passed to endpoint
        variables = {"eid": eid}
        # Perform POST request and check status code of response

        # Set base URL of GraphQL API endpoint
        base_url = "https://api.platform.opentargets.org/api/v4/graphql"

        # Perform POST request and check status code of response
        r = requests.post(base_url, json={"query": query_string, "variables": variables})
    #     print(r.status_code)
    #     tmp_text=r.text
    #     tmp_name = '\"' + name + '\"'
    #     tmp_text=tmp_text.replace("\"disease\"",tmp_name)
    #     print(tmp_text)
        # Transform API response into JSON 
    #     tmp_data = {'name':name,
    #                'drugs':api_response_as_json['data']['knownDrugs']['rows']['drugId']}
        api_response_as_json = json.loads(r.text)
        drugs = []
        for row in api_response_as_json['data']['disease']['knownDrugs']['rows']:
            drugs.append(row['drugId'])
        data2[api_response_as_json['data']['disease']['name']] = str(list(dict.fromkeys(drugs)))
    #     api_response_as_json['data']['knownDrugs']['rows']['drugId']
    #     # Print API response to terminal
    #     data = merge(data, api_response_as_json)
        print(api_response_as_json)
    except:
        continue
# Out:
# {'data': {'disease': {'name': 'acne', 'knownDrugs': {'rows': [{'drugId': 'CHEMBL1433', 'prefName': 'DOXYCYCLINE'}, {'drugId': 'CHEMBL1433', 'prefName': 'DOXYCYCLINE'}, {'drugId': 'CHEMBL1657', 'prefName': 'TAZAROTENE'}, {'drugId': 'CHEMBL79', 'prefName': 'LIDOCAINE'}, {'drugId': 'CHEMBL1433', 'prefName': 'DOXYCYCLINE'}, {'drugId': 'CHEMBL3989740', 'prefName': 'DOXYCYCLINE HYCLATE'}, {'drugId': 'CHEMBL1433', 'prefName': 'DOXYCYCLINE'}, {'drugId': 'CHEMBL79', 'prefName': 'LIDOCAINE'}, {'drugId': 'CHEMBL1265', 'prefName': 'ADAPALENE'}, {'drugId': 'CHEMBL38', 'prefName': 'TRETINOIN'}, {'drugId': 'CHEMBL1200699', 'prefName': 'DOXYCYCLINE'}, {'drugId': 'CHEMBL1433', 'prefName': 'DOXYCYCLINE'}, {'drugId': 'CHEMBL139835', 'prefName': 'CYPROTERONE ACETATE'}, {'drugId': 'CHEMBL1200934', 'prefName': 'NORGESTIMATE'}, {'drugId': 'CHEMBL547', 'prefName': 'ISOTRETINOIN'}, {'drugId': 'CHEMBL1433', 'prefName': 'DOXYCYCLINE'}, {'drugId': 'CHEMBL1200934', 'prefName': 'NORGESTIMATE'}, {'drugId': 'CHEMBL
# ...

# %%
with open('opentargets_data.json', 'w') as json_file:
    json.dump(data2, json_file)

# %%
for name,ids in returns:
    try:
        x = ast.literal_eval(data2[name])
        x = [n.strip() for n in x]
        print(len(x), name)
    except:
        print(0, name)
# Out:
# 11 acne
# 6 actinic keratosis
# 9 acute lung injury
# 6 acute pancreatitis
# 10 lung adenocarcinoma
# 13 adenoma
# 0 alcoholic psychosis
# 0 Alexander disease
# 6 acute myeloid leukemia
# 0 anaplasmosis
# 0 Androgen insensitivity syndrome
# 5 appendicitis
# 2 Arrhythmogenic right ventricular dysplasia
# 17 atopic eczema
# 19 asthma
# 11 astrocytoma
# 11 atherosclerosis
# 11 bacterial disease
# 14 Barrett's esophagus
# 15 bipolar disorder
# 15 breast cancer
# 11 malignant colon neoplasm
# 10 prostate adenocarcinoma
# 20 skin cancer
# 7 thyroid carcinoma
# 13 adenocarcinoma
# 21 heart failure
# 14 cardiac hypertrophy
# 0 autosomal dominant dilated cardiomyopathy
# 14 cardiomyopathy
# 6 chronic myelogenous leukemia
# 19 chronic obstructive pulmonary disease
# 10 Cystic fibrosis
# 0 Pseudohypoaldosteronism type 1
# 19 unipolar depression
# 14 dermatomyositis
# 15 diabetic nephropathy
# 12 diabetic neuropathy
# 6 Down syndrome
# 13 Duchenne muscular dystrophy
# 9 Eczema
# ...

# %% [markdown]
# with open('data.json') as f:
#     data2 = json.load(f)

# %% [markdown]
# drugs = []
# for row in api_response_as_json['data']['disease']['knownDrugs']['rows']:
#     drugs.append(row['drugId'])
# str(list(dict.fromkeys(drugs)))

# %% [markdown]
# data2[api_response_as_json['data']['disease']['name']] = str(list(dict.fromkeys(drugs)))
